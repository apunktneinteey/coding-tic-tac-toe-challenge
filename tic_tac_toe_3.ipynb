# %%
#DEFINE filename to start script in terminal
#DEFINE function user_input
    #INPUT username
#DEFINE function icon (X or O)
    #STORE global iconlist
        #ASK for userinput (icon)
        #WHILE input input is not correct:
            #PRINT choose X or O
            #IF icon correct:
                #BREAK
        #IF icon1 X 
            #-> icon2 O
        #ELIF icon1 O 
            #-> icon2 X
        #ADD icons to iconlist
#DEFINE function for display
    #STORE display    

#DEF Funktion switch player
    #IF player 0 
        #-> player 1
    #ELSE player 0

#DEF Function switch icon
    #IF icon 0 
        #-> icon 1
    #ELSE icon 0

#DEF Function win(game_running)
    #(game running = TRUE)
    #if ...
        #game running = FALSE

#DEF Function draw(game_running)
    #IF condition: True
    #Else: False
    #(game running = TRUE)

#Def Function player turn
  #STORE Player_playing
    #STORE ICON_playing
    #STORE display
    #WHILE game_running:
    #WHILE no win or draw, loop keeps on going
        #IF win or draw --> break 
            #PRINT name(winner) or draw
    #ELSE: continue
    #STORE USERINPUT number
    #STORE INT(USERINPUT)
    #REPLACE number in display[USERINPUT] with ICON_playing
    #SHOW display
    #CALL Function switch player
    #call function switch icon
        

#DEF Function play-game
    #STORE Variable Game_running = TRUE
    #CALL Function player turn

# %%
#DEFINE function user_input
    #INPUT username


def input_username():
    #global names
    names = []
    name_1 = input('Please insert your name:')
    name_2 = input('Please insert your name:')
    names.append(name_1)
    names.append(name_2)
    print(f'Hi {name_1} and {name_2} let\'s play tick tack toe!')
    print(f'{name_1} next choose your icon, please.')
    return names





#input_username()

# %%
#DEFINE function user_input
    
def input_usericon(names):
    #global icons
    icons = []
    icon_1 = input('Please choose your icon (X or O):')
    while icon_1 != 'X' and icon_1 != 'O':               
        print('Only enter X or O, please.')
        icon_1 = input('Please choose your icon (X or O):')
        if icon_1 == 'X' or icon_1 == 'O':
            break
    if icon_1 == 'X':
        icon_2 = 'O'
    elif icon_1 == 'O':
        icon_2 = 'X'
    icons.append(icon_1)
    icons.append(icon_2)
    print(names[0] + f' your icon is {icon_1}.')
    print(names[1] + f' your icon is {icon_2}.')
    print(' ')
    return icons

#names = input_username()
#input_usericon(names)

# %%
#DEFINE function for display

display = [[1,2,3], [4,5,6],[7,8,9]]

def show_display_1(display):
    for x in display:
        print(*x)

# %%
#DEFINE function for display

display = ['some variable', 1, 2, 3, 4, 5, 6, 7, 8, 9]

def show_display_2(display):
    print(display[1], '|', display[2], '|', display[3])
    print('---------')
    print(display[4], '|', display[5], '|', display[6])
    print('---------')
    print(display[7], '|', display[8], '|', display[9])

# %%
#DEF Funktion switch player
    #IF player 0 
        #-> player 1
    #ELSE player 0

#DEF Function switch icon
    #IF icon 0 
        #-> icon 1
    #ELSE icon 0

#DEF Function win(game_running)
    #(game running = TRUE)
    #if ...
        #game running = FALSE

#DEF Function draw(game_running)
    #(game running = TRUE)

#Def Function player turn
    #STORE Player_playing
    #STORE ICON_playing
    #STORE display
    #WHILE game_running:
        #STORE USERINPUT number
        #STORE INT(USERINPUT)
        #REPLACE number in display[USERINPUT] with ICON_playing
        #SHOW display
        #CALL Function switch player
        #call function switch icon
        

#DEF Function play-game
    #STORE Variable Game_running = TRUE
    #CALL Function player turn

# %%
def switch_playing_name(playing_name, names):
    if playing_name == names[0]:
        playing_name = names[1]
    else:
        playing_name = names[0]
    return playing_name

def switch_playing_icon(playing_icon, icons):
    if playing_icon == icons[0]:
        playing_icon = icons[1]
    else:
        playing_icon = icons[0]
    return playing_icon

# %%
#DEF Function win(game_running)
    #(game running = TRUE)
    #if ...
        #game running = FALSE
# x , 2 , 3
# x , 5 , 6
# x , 8 , 9
game_running = True
display = ['some variable', 1, 2, 3, 4, 5, 6, 7, 8, 9]

def win(game_running, display):
    #winlist = []
    if display[1] == display[4] and display[1] == display[7]:
        game_running =  False
    elif display[2] == display[5] and display[2] == display[8]:
        game_running =  False
    elif display[3] == display[6] and display[3] == display[9]:
        game_running =  False
    elif display[1] == display[2] and display[1] == display[3]:
        game_running =  False
    elif display[4] == display[5] and display[4] == display[6]:
        game_running =  False
    elif display[7] == display[8] and display[7] == display[9]:
        game_running =  False
    elif display[1] == display[5] and display[1] == display[9]:
        game_running =  False
    elif display[3] == display[5] and display[3 ]== display[7]:
        game_running =  False
    if game_running == False:
        print('We have a winner')
    return game_running
    #winlist.append(win1)
    #print(winlist)

# %%
win(game_running, display)
# Out:
# True

# %%
#DEF Function draw(game_running)
def draw(count_rounds, game_running): 
    if count_rounds >= 9:
        game_running = False 
    return game_running

# %%
#DEFINE player turns
def player_turns(names, icons, game_running): #evtl. muss count_rounds hier noch dazu
    playing_name = names[0]
    playing_icon = icons[0]
    display = ['some variable', 1, 2, 3, 4, 5, 6, 7, 8, 9]
    count_rounds = 1
    while game_running:
        print("  ")
        print(playing_name + (", please enter a number between 1 and 9:"))
        print("  ")
        user_input = int(input('please enter a number between 1 and 9:'))
        display[user_input] = playing_icon
        show_display_2(display)
        game_running = draw(count_rounds, game_running)
        if game_running == False:
            print('We have a draw')
            break
        game_running = win(game_running, display)
        if game_running == False:
            print(playing_name + ' is the winner')       #das muss noch in die win function
            break
        count_rounds += 1
        playing_name = switch_playing_name(playing_name, names)
        playing_icon = switch_playing_icon(playing_icon, icons)
    return count_rounds

# %%
def play_game():
    #input_username()
    names = input_username()
    #input_usericon(names)
    icons = input_usericon(names)
    show_display_2(display)
    #global game_running
    #game_running = True
    win(game_running, display)
    player_turns(names, icons, game_running)
    
   

play_game()
# Out:
# Hi Anna and Tim let's play tick tack toe!
# Anna next choose your icon, please.
# Anna your icon is X.
# Tim your icon is O.
#
# 1 | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 9
#
# Anna, please enter a number between 1 and 9:
#
# X | 2 | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 9
#
# Tim, please enter a number between 1 and 9:
#
# X | O | 3
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 9
#
# Anna, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# 4 | 5 | 6
# ---------
# 7 | 8 | 9
#
# Tim, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# O | 5 | 6
# ---------
# 7 | 8 | 9
#
# Anna, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# O | X | 6
# ---------
# 7 | 8 | 9
#
# Tim, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# O | X | 6
# ---------
# O | 8 | 9
#
# Anna, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# O | X | X
# ---------
# O | 8 | 9
#
# Tim, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# O | X | X
# ---------
# O | 8 | O
#
# Anna, please enter a number between 1 and 9:
#
# X | O | X
# ---------
# O | X | X
# ---------
# O | X | O
# We have a draw
